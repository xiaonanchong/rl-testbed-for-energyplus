# %%
import baselines
# !. /home/xiaonanchong/venv/rl/bin/activate

# %%
# !python3 -m baselines.run --alg=ppo2 --env=PongNoFrameskip-v4 --num_timesteps=2e7 --save_path=~/models/pong_20M_ppo2
# Out:
# /home/xiaonanchong/venv/rl/bin/python3: No module named baselines.run

# %% [markdown]
# https://github.com/openai/baselines/blob/master/docs/viz/viz.ipynb

# %%
# !pip install git+https://github.com/openai/baselines > ~/pip_install_baselines.log
# Out:
#   Running command git clone -q https://github.com/openai/baselines /tmp/pip-req-build-xvwnzztk

# %%
# !OPENAI_LOGDIR=$HOME/logs/cartpole-ppo OPENAI_LOG_FORMAT=csv python -m baselines.run --alg=ppo2 --env=CartPole-v0 --num_timesteps=30000 --nsteps=128
# Out:
# /home/xiaonanchong/venv/rl/bin/python: No module named baselines.run

# %% [markdown]
# after installing latest version of baselines

# %%
# !pip install git+https://github.com/openai/baselines > ~/pip_install_baselines.log
# Out:
#   Running command git clone -q https://github.com/openai/baselines /tmp/pip-req-build-3yzy3ui2

# %%
# !OPENAI_LOGDIR=$HOME/logs/building_5e20 OPENAI_LOG_FORMAT=csv python -m baselines.run --alg=trpo_mpi --env='gym_energyplus:EnergyPlus-v0' --num_timesteps=5e20
# Out:
# env_type: gym_energyplus
# 2019-05-29 13:09:06.474981: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2401000000 Hz
# 2019-05-29 13:09:06.477808: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5a2b7c0 executing computations on platform Host. Devices:
# 2019-05-29 13:09:06.477951: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# Training trpo_mpi on gym_energyplus:gym_energyplus:EnergyPlus-v0 with arguments
# {'network': 'mlp'}
# WARNING:tensorflow:From /home/xiaonanchong/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/xiaonanchong/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
from baselines.common import plot_util as pu
results = pu.load_results('~/logs/building_5e20)


import matplotlib.pyplot as plt
import numpy as np
r = results[0]
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
# Out:
#   File "<ipython-input-23-6b9755dd3198>", line 2
#     results = pu.load_results('~/logs/building_5e20)
#                                                     ^
# SyntaxError: EOL while scanning string literal
